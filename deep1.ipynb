# %%
import gym 
import torch
from  torch.autograd import Variable
import random

# %%
class DQN():
    def __init__(self, n_state, n_action, n_hidden = 50, lr= 0.05):
        self.criterion = torch.nn.MSELoss()
        self.model = torch.nn.Sequential(
            torch.nn.Linear(n_state, n_hidden),
            torch.nn.ReLU(),
            torch.nn.Linear(n_hidden, n_action)
        )

        self.optimizer = torch.optim.Adam(
            self.model.parameters(),lr
        )
    def update(self, s,y):
        """
        Update the weights of the DQN given a training sample
        @param s : state
        @param y: target value
        """

        y_pred = self.model(torch.Tensor(s))
        loss = self.criterion(y_pred, Variable(torch.Tensor(y)))
        self.optimizer.zero_grad()
        loss.backward()
        self.optimizer.step()

    def predict(self, s ):
        with torch.no_grad():
            return self.model(torch.Tensor(s))
        print("going on")

# %%
env = gym.envs.make("MountainCar-v0")

# %%
def gen_epsilon_greedy_policy(estimator, epsilon , n_action):
    def policy_function(state):
        if random.random() < epsilon:
            return random.randint(0, n_action -1 )

        else :
            q_values = estimator.predict(state)
            return torch.argmax(q_values).item()

    return policy_function

# %%
def q_learning(env, estimator, n_episode, gamma = 1.0 , epsilon =0.1 , epsilon_decay = 0.99):
    for episode in range(n_episode):
        policy = gen_epsilon_greedy_policy(estimator, epsilon , n_action)
        state,_ = env.reset()
        #print("state",state)
        is_done = False
        while not is_done:
            action = policy(state)
            next_state , reward, is_done,_,_ = env.step(action)
            #print("next_state",next_state)
            total_reward_episode[episode] += reward 
            modified_reward = next_state[0] + 0.5
            if next_state[0] >= 0.5:
                modified_reward += 100

            elif next_state[0] >=0.25:
                modified_reward += 20

            elif next_state[0] >= 0.1:
                modified_reward += 10

            elif next_state[0] >= 0 :
                modified_reward += 5
            
            q_values = estimator.predict(state).tolist()

            if is_done:
                q_values[action] = modified_reward
                estimator.update(state,q_values)
                break
            
            q_values_next = estimator.predict(next_state)
            q_values[action] = modified_reward +  gamma * torch.max(q_values_next).item()
            estimator.update(state,q_values)
            state = next_state
        
        print(' episode :{} , total reward:{}, epsilon:{}'.format(episode, total_reward_episode[episode] , epsilon))

        epsilon = max(epsilon * epsilon_decay, 0.01)

# %%
n_state = env.observation_space.shape[0]
n_action = env.action_space.n
n_hidden = 50 
lr = 0.001
dqn = DQN (n_state, n_action, n_hidden, lr)
n_state
# Out:
# 2

# %%
n_episode  =1000
total_reward_episode = [0] * n_episode
q_learning(env,dqn, n_episode, gamma=0.99, epsilon =0.3)
# Out:
#  episode :0 , total reward:-8969.0, epsilon:0.3
#  episode :1 , total reward:-726.0, epsilon:0.297
#  episode :2 , total reward:-823.0, epsilon:0.29402999999999996
#  episode :3 , total reward:-1147.0, epsilon:0.29108969999999995
#  episode :4 , total reward:-642.0, epsilon:0.28817880299999993
#  episode :5 , total reward:-758.0, epsilon:0.28529701496999993
#  episode :6 , total reward:-1576.0, epsilon:0.28244404482029994
#  episode :7 , total reward:-791.0, epsilon:0.27961960437209693
#  episode :8 , total reward:-1076.0, epsilon:0.276823408328376
#  episode :9 , total reward:-567.0, epsilon:0.27405517424509224
#  episode :10 , total reward:-1565.0, epsilon:0.2713146225026413
#  episode :11 , total reward:-678.0, epsilon:0.2686014762776149
#  episode :12 , total reward:-633.0, epsilon:0.26591546151483875
#  episode :13 , total reward:-765.0, epsilon:0.2632563068996904
#  episode :14 , total reward:-599.0, epsilon:0.2606237438306935
#  episode :15 , total reward:-509.0, epsilon:0.2580175063923865
#  episode :16 , total reward:-626.0, epsilon:0.25543733132846264
#  episode :17 , total reward:-689.0, epsilon:0.252882958015178
#  episode :18 , total reward:-779.0, epsilon:0.25035412843502625
#  episode :19 , total reward:-724.0, epsilon:0.24785058715067598
#  episode :20 , total reward:-1058.0, epsilon:0.2453720812791692
#  episode :21 , total reward:-633.0, epsilon:0.24291836046637752
#  episode :22 , total reward:-2378.0, epsilon:0.24048917686171375
#  episode :23 , total reward:-574.0, epsilon:0.23808428509309662
#  episode :24 , total reward:-689.0, epsilon:0.23570344224216566
#  episode :25 , total reward:-820.0, epsilon:0.233346407819744
#  episode :26 , total reward:-971.0, epsilon:0.23101294374154654
#  episode :27 , total reward:-1673.0, epsilon:0.22870281430413109
#  episode :28 , total reward:-1288.0, epsilon:0.22641578616108976
#  episode :29 , total reward:-1747.0, epsilon:0.22415162829947885
#  episode :30 , total reward:-817.0, epsilon:0.22191011201648406
#  episode :31 , total reward:-943.0, epsilon:0.2196910108963192
#  episode :32 , total reward:-1136.0, epsilon:0.217494100787356
#  episode :33 , total reward:-1500.0, epsilon:0.21531915977948246
#  episode :34 , total reward:-782.0, epsilon:0.21316596818168762
#  episode :35 , total reward:-1026.0, epsilon:0.21103430849987073
#  episode :36 , total reward:-473.0, epsilon:0.20892396541487201
#  episode :37 , total reward:-609.0, epsilon:0.2068347257607233
#  episode :38 , total reward:-516.0, epsilon:0.20476637850311605
#  episode :39 , total reward:-697.0, epsilon:0.2027187147180849
#  episode :40 , total reward:-608.0, epsilon:0.20069152757090403
#  episode :41 , total reward:-642.0, epsilon:0.198684612295195
#  episode :42 , total reward:-879.0, epsilon:0.19669776617224305
#  episode :43 , total reward:-920.0, epsilon:0.1947307885105206
#  episode :44 , total reward:-723.0, epsilon:0.1927834806254154
#  episode :45 , total reward:-1021.0, epsilon:0.19085564581916123
#  episode :46 , total reward:-862.0, epsilon:0.18894708936096963
#  episode :47 , total reward:-972.0, epsilon:0.18705761846735994
#  episode :48 , total reward:-1151.0, epsilon:0.18518704228268634
#  episode :49 , total reward:-1779.0, epsilon:0.18333517185985948
#  episode :50 , total reward:-841.0, epsilon:0.18150182014126087
#  episode :51 , total reward:-851.0, epsilon:0.17968680193984826
#  episode :52 , total reward:-1024.0, epsilon:0.17788993392044977
#  episode :53 , total reward:-976.0, epsilon:0.17611103458124527
#  episode :54 , total reward:-891.0, epsilon:0.17434992423543283
#  episode :55 , total reward:-769.0, epsilon:0.1726064249930785
#  episode :56 , total reward:-922.0, epsilon:0.1708803607431477
#  episode :57 , total reward:-694.0, epsilon:0.16917155713571622
#  episode :58 , total reward:-610.0, epsilon:0.16747984156435905
#  episode :59 , total reward:-745.0, epsilon:0.16580504314871547
#  episode :60 , total reward:-727.0, epsilon:0.16414699271722832
#  episode :61 , total reward:-612.0, epsilon:0.16250552279005603
#  episode :62 , total reward:-924.0, epsilon:0.16088046756215546
#  episode :63 , total reward:-664.0, epsilon:0.1592716628865339
#  episode :64 , total reward:-598.0, epsilon:0.15767894625766857
#  episode :65 , total reward:-765.0, epsilon:0.15610215679509187
#  episode :66 , total reward:-667.0, epsilon:0.15454113522714094
#  episode :67 , total reward:-754.0, epsilon:0.15299572387486954
#  episode :68 , total reward:-771.0, epsilon:0.15146576663612085
#  episode :69 , total reward:-623.0, epsilon:0.14995110896975963
#  episode :70 , total reward:-820.0, epsilon:0.14845159788006204
#  episode :71 , total reward:-888.0, epsilon:0.14696708190126143
#  episode :72 , total reward:-1488.0, epsilon:0.1454974110822488
#  episode :73 , total reward:-841.0, epsilon:0.14404243697142632
#  episode :74 , total reward:-1758.0, epsilon:0.14260201260171207
#  episode :75 , total reward:-1099.0, epsilon:0.14117599247569496
#  episode :76 , total reward:-817.0, epsilon:0.139764232550938
#  episode :77 , total reward:-1391.0, epsilon:0.13836659022542863
#  episode :78 , total reward:-1401.0, epsilon:0.13698292432317435
#  episode :79 , total reward:-806823.0, epsilon:0.1356130950799426
#  episode :80 , total reward:-4968.0, epsilon:0.13425696412914317
#  episode :81 , total reward:-684.0, epsilon:0.13291439448785175
#  episode :82 , total reward:-678.0, epsilon:0.13158525054297324
#  episode :83 , total reward:-579.0, epsilon:0.1302693980375435
#  episode :84 , total reward:-563.0, epsilon:0.12896670405716806
#  episode :85 , total reward:-790.0, epsilon:0.12767703701659638
#  episode :86 , total reward:-625.0, epsilon:0.12640026664643042
#  episode :87 , total reward:-991.0, epsilon:0.1251362639799661
#  episode :88 , total reward:-786.0, epsilon:0.12388490134016644
#  episode :89 , total reward:-812.0, epsilon:0.12264605232676477
#  episode :90 , total reward:-1982.0, epsilon:0.12141959180349712
#  episode :91 , total reward:-1095.0, epsilon:0.12020539588546215
#  episode :92 , total reward:-1637.0, epsilon:0.11900334192660753
#  episode :93 , total reward:-960.0, epsilon:0.11781330850734145
#  episode :94 , total reward:-1871.0, epsilon:0.11663517542226803
#  episode :95 , total reward:-6732.0, epsilon:0.11546882366804535
#  episode :96 , total reward:-3037.0, epsilon:0.1143141354313649
#  episode :97 , total reward:-1152.0, epsilon:0.11317099407705125
#  episode :98 , total reward:-1980.0, epsilon:0.11203928413628074
#  episode :99 , total reward:-1261.0, epsilon:0.11091889129491793
#  episode :100 , total reward:-592.0, epsilon:0.10980970238196874
#  episode :101 , total reward:-1480.0, epsilon:0.10871160535814905
#  episode :102 , total reward:-680.0, epsilon:0.10762448930456757
#  episode :103 , total reward:-1822.0, epsilon:0.10654824441152189
#  episode :104 , total reward:-788.0, epsilon:0.10548276196740666
#  episode :105 , total reward:-685.0, epsilon:0.10442793434773259
#  episode :106 , total reward:-638.0, epsilon:0.10338365500425527
#  episode :107 , total reward:-841.0, epsilon:0.10234981845421272
#  episode :108 , total reward:-930.0, epsilon:0.10132632026967059
#  episode :109 , total reward:-935.0, epsilon:0.10031305706697388
#  episode :110 , total reward:-958.0, epsilon:0.09930992649630414
#  episode :111 , total reward:-1116.0, epsilon:0.0983168272313411
#  episode :112 , total reward:-895.0, epsilon:0.09733365895902768
#  episode :113 , total reward:-777.0, epsilon:0.0963603223694374
#  episode :114 , total reward:-838.0, epsilon:0.09539671914574302
#  episode :115 , total reward:-806.0, epsilon:0.09444275195428559
#  episode :116 , total reward:-953.0, epsilon:0.09349832443474274
#  episode :117 , total reward:-846.0, epsilon:0.0925633411903953
#  episode :118 , total reward:-914.0, epsilon:0.09163770777849135
#  episode :119 , total reward:-738.0, epsilon:0.09072133070070644
#  episode :120 , total reward:-770.0, epsilon:0.08981411739369938
#  episode :121 , total reward:-683.0, epsilon:0.08891597621976238
#  episode :122 , total reward:-867.0, epsilon:0.08802681645756476
#  episode :123 , total reward:-866.0, epsilon:0.08714654829298911
#  episode :124 , total reward:-864.0, epsilon:0.08627508281005922
#  episode :125 , total reward:-810.0, epsilon:0.08541233198195862
#  episode :126 , total reward:-791.0, epsilon:0.08455820866213903
#  episode :127 , total reward:-746.0, epsilon:0.08371262657551765
#  episode :128 , total reward:-919.0, epsilon:0.08287550030976247
#  episode :129 , total reward:-881.0, epsilon:0.08204674530666485
#  episode :130 , total reward:-1015.0, epsilon:0.0812262778535982
#  episode :131 , total reward:-777.0, epsilon:0.08041401507506223
#  episode :132 , total reward:-758.0, epsilon:0.0796098749243116
#  episode :133 , total reward:-884.0, epsilon:0.07881377617506848
#  episode :134 , total reward:-926.0, epsilon:0.07802563841331779
#  episode :135 , total reward:-709.0, epsilon:0.07724538202918461
#  episode :136 , total reward:-687.0, epsilon:0.07647292820889277
#  episode :137 , total reward:-847.0, epsilon:0.07570819892680385
#  episode :138 , total reward:-897.0, epsilon:0.07495111693753581
#  episode :139 , total reward:-558.0, epsilon:0.07420160576816046
#  episode :140 , total reward:-905.0, epsilon:0.07345958971047885
#  episode :141 , total reward:-491.0, epsilon:0.07272499381337406
#  episode :142 , total reward:-817.0, epsilon:0.07199774387524033
#  episode :143 , total reward:-688.0, epsilon:0.07127776643648792
#  episode :144 , total reward:-1016.0, epsilon:0.07056498877212304
#  episode :145 , total reward:-823.0, epsilon:0.06985933888440181
#  episode :146 , total reward:-929.0, epsilon:0.06916074549555778
#  episode :147 , total reward:-860.0, epsilon:0.0684691380406022
#  episode :148 , total reward:-722.0, epsilon:0.06778444666019617
#  episode :149 , total reward:-685.0, epsilon:0.06710660219359421
#  episode :150 , total reward:-1145.0, epsilon:0.06643553617165827
#  episode :151 , total reward:-892.0, epsilon:0.0657711808099417
#  episode :152 , total reward:-488.0, epsilon:0.06511346900184228
#  episode :153 , total reward:-930.0, epsilon:0.06446233431182385
#  episode :154 , total reward:-810.0, epsilon:0.06381771096870562
#  episode :155 , total reward:-756.0, epsilon:0.06317953385901856
#  episode :156 , total reward:-523.0, epsilon:0.06254773852042837
#  episode :157 , total reward:-895.0, epsilon:0.06192226113522409
#  episode :158 , total reward:-759.0, epsilon:0.061303038523871846
#  episode :159 , total reward:-755.0, epsilon:0.06069000813863313
#  episode :160 , total reward:-829.0, epsilon:0.0600831080572468
#  episode :161 , total reward:-831.0, epsilon:0.05948227697667433
#  episode :162 , total reward:-1006.0, epsilon:0.05888745420690759
#  episode :163 , total reward:-772.0, epsilon:0.058298579664838514
#  episode :164 , total reward:-837.0, epsilon:0.057715593868190126
#  episode :165 , total reward:-675.0, epsilon:0.05713843792950823
#  episode :166 , total reward:-556.0, epsilon:0.056567053550213145
#  episode :167 , total reward:-743.0, epsilon:0.05600138301471101
#  episode :168 , total reward:-528.0, epsilon:0.0554413691845639
#  episode :169 , total reward:-1037.0, epsilon:0.05488695549271826
#  episode :170 , total reward:-763.0, epsilon:0.05433808593779108
#  episode :171 , total reward:-439.0, epsilon:0.05379470507841317
#  episode :172 , total reward:-1002.0, epsilon:0.05325675802762904
#  episode :173 , total reward:-525.0, epsilon:0.05272419044735275
#  episode :174 , total reward:-902.0, epsilon:0.05219694854287922
#  episode :175 , total reward:-948.0, epsilon:0.05167497905745043
#  episode :176 , total reward:-734.0, epsilon:0.051158229266875924
#  episode :177 , total reward:-407.0, epsilon:0.05064664697420716
#  episode :178 , total reward:-879.0, epsilon:0.050140180504465094
#  episode :179 , total reward:-771.0, epsilon:0.04963877869942044
#  episode :180 , total reward:-973.0, epsilon:0.04914239091242623
#  episode :181 , total reward:-672.0, epsilon:0.04865096700330197
#  episode :182 , total reward:-718.0, epsilon:0.048164457333268955
#  episode :183 , total reward:-610.0, epsilon:0.047682812759936265
#  episode :184 , total reward:-816.0, epsilon:0.047205984632336905
#  episode :185 , total reward:-723.0, epsilon:0.046733924786013535
#  episode :186 , total reward:-454.0, epsilon:0.0462665855381534
#  episode :187 , total reward:-684.0, epsilon:0.045803919682771865
#  episode :188 , total reward:-386.0, epsilon:0.045345880485944144
#  episode :189 , total reward:-1040.0, epsilon:0.044892421681084704
#  episode :190 , total reward:-453.0, epsilon:0.044443497464273854
#  episode :191 , total reward:-897.0, epsilon:0.04399906248963111
#  episode :192 , total reward:-556.0, epsilon:0.0435590718647348
#  episode :193 , total reward:-541.0, epsilon:0.04312348114608745
#  episode :194 , total reward:-759.0, epsilon:0.04269224633462658
#  episode :195 , total reward:-609.0, epsilon:0.04226532387128031
#  episode :196 , total reward:-374.0, epsilon:0.04184267063256751
#  episode :197 , total reward:-415.0, epsilon:0.04142424392624183
#  episode :198 , total reward:-722.0, epsilon:0.04101000148697941
#  episode :199 , total reward:-752.0, epsilon:0.040599901472109616
#  episode :200 , total reward:-589.0, epsilon:0.04019390245738852
#  episode :201 , total reward:-558.0, epsilon:0.03979196343281463
#  episode :202 , total reward:-489.0, epsilon:0.03939404379848648
#  episode :203 , total reward:-764.0, epsilon:0.039000103360501616
#  episode :204 , total reward:-436.0, epsilon:0.0386101023268966
#  episode :205 , total reward:-963.0, epsilon:0.03822400130362764
#  episode :206 , total reward:-411.0, epsilon:0.03784176129059136
#  episode :207 , total reward:-712.0, epsilon:0.037463343677685446
#  episode :208 , total reward:-603.0, epsilon:0.03708871024090859
#  episode :209 , total reward:-458.0, epsilon:0.0367178231384995
#  episode :210 , total reward:-910.0, epsilon:0.0363506449071145
#  episode :211 , total reward:-925.0, epsilon:0.035987138458043355
#  episode :212 , total reward:-899.0, epsilon:0.03562726707346292
#  episode :213 , total reward:-285.0, epsilon:0.03527099440272829
#  episode :214 , total reward:-626.0, epsilon:0.034918284458701
#  episode :215 , total reward:-781.0, epsilon:0.034569101614113994
#  episode :216 , total reward:-741.0, epsilon:0.034223410597972855
#  episode :217 , total reward:-250.0, epsilon:0.033881176491993126
#  episode :218 , total reward:-393.0, epsilon:0.03354236472707319
#  episode :219 , total reward:-996.0, epsilon:0.03320694107980246
#  episode :220 , total reward:-433.0, epsilon:0.032874871669004435
#  episode :221 , total reward:-366.0, epsilon:0.03254612295231439
#  episode :222 , total reward:-803.0, epsilon:0.03222066172279125
#  episode :223 , total reward:-291.0, epsilon:0.031898455105563335
#  episode :224 , total reward:-1050.0, epsilon:0.0315794705545077
#  episode :225 , total reward:-237.0, epsilon:0.03126367584896263
#  episode :226 , total reward:-635.0, epsilon:0.030951039090473
#  episode :227 , total reward:-684.0, epsilon:0.03064152869956827
#  episode :228 , total reward:-560.0, epsilon:0.030335113412572588
#  episode :229 , total reward:-897.0, epsilon:0.030031762278446863
#  episode :230 , total reward:-601.0, epsilon:0.029731444655662395
#  episode :231 , total reward:-461.0, epsilon:0.02943413020910577
#  episode :232 , total reward:-1070.0, epsilon:0.029139788907014713
#  episode :233 , total reward:-930.0, epsilon:0.028848391017944567
#  episode :234 , total reward:-453.0, epsilon:0.028559907107765122
#  episode :235 , total reward:-1204.0, epsilon:0.02827430803668747
#  episode :236 , total reward:-333.0, epsilon:0.027991564956320596
#  episode :237 , total reward:-971.0, epsilon:0.027711649306757388
#  episode :238 , total reward:-843.0, epsilon:0.027434532813689815
#  episode :239 , total reward:-653.0, epsilon:0.027160187485552916
#  episode :240 , total reward:-305.0, epsilon:0.026888585610697388
#  episode :241 , total reward:-286.0, epsilon:0.026619699754590415
#  episode :242 , total reward:-1008.0, epsilon:0.02635350275704451
#  episode :243 , total reward:-359.0, epsilon:0.026089967729474067
#  episode :244 , total reward:-873.0, epsilon:0.025829068052179327
#  episode :245 , total reward:-249.0, epsilon:0.025570777371657534
#  episode :246 , total reward:-360.0, epsilon:0.02531506959794096
#  episode :247 , total reward:-623.0, epsilon:0.02506191890196155
#  episode :248 , total reward:-491.0, epsilon:0.024811299712941933
#  episode :249 , total reward:-280.0, epsilon:0.024563186715812514
#  episode :250 , total reward:-979.0, epsilon:0.024317554848654388
#  episode :251 , total reward:-679.0, epsilon:0.024074379300167845
#  episode :252 , total reward:-326.0, epsilon:0.023833635507166166
#  episode :253 , total reward:-944.0, epsilon:0.023595299152094504
#  episode :254 , total reward:-408.0, epsilon:0.023359346160573558
#  episode :255 , total reward:-462.0, epsilon:0.02312575269896782
#  episode :256 , total reward:-299.0, epsilon:0.02289449517197814
#  episode :257 , total reward:-713.0, epsilon:0.02266555022025836
#  episode :258 , total reward:-593.0, epsilon:0.022438894718055775
#  episode :259 , total reward:-405.0, epsilon:0.022214505770875217
#  episode :260 , total reward:-711.0, epsilon:0.021992360713166466
#  episode :261 , total reward:-612.0, epsilon:0.0217724371060348
#  episode :262 , total reward:-704.0, epsilon:0.021554712734974453
#  episode :263 , total reward:-540.0, epsilon:0.021339165607624708
#  episode :264 , total reward:-342.0, epsilon:0.021125773951548462
#  episode :265 , total reward:-754.0, epsilon:0.020914516212032976
#  episode :266 , total reward:-520.0, epsilon:0.020705371049912647
#  episode :267 , total reward:-394.0, epsilon:0.02049831733941352
#  episode :268 , total reward:-986.0, epsilon:0.020293334166019385
#  episode :269 , total reward:-726.0, epsilon:0.02009040082435919
#  episode :270 , total reward:-364.0, epsilon:0.0198894968161156
#  episode :271 , total reward:-774.0, epsilon:0.01969060184795444
#  episode :272 , total reward:-771.0, epsilon:0.019493695829474897
#  episode :273 , total reward:-291.0, epsilon:0.019298758871180148
#  episode :274 , total reward:-666.0, epsilon:0.019105771282468348
#  episode :275 , total reward:-927.0, epsilon:0.018914713569643665
#  episode :276 , total reward:-802.0, epsilon:0.018725566433947228
#  episode :277 , total reward:-361.0, epsilon:0.018538310769607755
#  episode :278 , total reward:-963.0, epsilon:0.018352927661911676
#  episode :279 , total reward:-913.0, epsilon:0.018169398385292558
#  episode :280 , total reward:-765.0, epsilon:0.01798770440143963
#  episode :281 , total reward:-428.0, epsilon:0.017807827357425234
#  episode :282 , total reward:-1141.0, epsilon:0.017629749083850982
#  episode :283 , total reward:-348.0, epsilon:0.01745345159301247
#  episode :284 , total reward:-496.0, epsilon:0.017278917077082345
#  episode :285 , total reward:-1011.0, epsilon:0.01710612790631152
#  episode :286 , total reward:-318.0, epsilon:0.016935066627248405
#  episode :287 , total reward:-827.0, epsilon:0.01676571596097592
#  episode :288 , total reward:-387.0, epsilon:0.01659805880136616
#  episode :289 , total reward:-500.0, epsilon:0.016432078213352498
#  episode :290 , total reward:-356.0, epsilon:0.016267757431218974
#  episode :291 , total reward:-1345.0, epsilon:0.016105079856906783
#  episode :292 , total reward:-721.0, epsilon:0.015944029058337715
#  episode :293 , total reward:-749.0, epsilon:0.015784588767754338
#  episode :294 , total reward:-822.0, epsilon:0.015626742880076795
#  episode :295 , total reward:-1110.0, epsilon:0.015470475451276028
#  episode :296 , total reward:-347.0, epsilon:0.015315770696763268
#  episode :297 , total reward:-567.0, epsilon:0.015162612989795635
#  episode :298 , total reward:-1081.0, epsilon:0.015010986859897678
#  episode :299 , total reward:-456.0, epsilon:0.014860876991298701
#  episode :300 , total reward:-272.0, epsilon:0.014712268221385714
#  episode :301 , total reward:-1304.0, epsilon:0.014565145539171856
#  episode :302 , total reward:-456.0, epsilon:0.014419494083780137
#  episode :303 , total reward:-1523.0, epsilon:0.014275299142942335
#  episode :304 , total reward:-933.0, epsilon:0.014132546151512911
#  episode :305 , total reward:-274.0, epsilon:0.013991220689997782
#  episode :306 , total reward:-1074.0, epsilon:0.013851308483097803
#  episode :307 , total reward:-837.0, epsilon:0.013712795398266824
#  episode :308 , total reward:-275.0, epsilon:0.013575667444284156
#  episode :309 , total reward:-642.0, epsilon:0.013439910769841315
#  episode :310 , total reward:-1312.0, epsilon:0.013305511662142902
#  episode :311 , total reward:-1005.0, epsilon:0.013172456545521473
#  episode :312 , total reward:-870.0, epsilon:0.013040731980066257
#  episode :313 , total reward:-346.0, epsilon:0.012910324660265595
#  episode :314 , total reward:-561.0, epsilon:0.012781221413662938
#  episode :315 , total reward:-1390.0, epsilon:0.012653409199526308
#  episode :316 , total reward:-239.0, epsilon:0.012526875107531045
#  episode :317 , total reward:-344.0, epsilon:0.012401606356455734
#  episode :318 , total reward:-881.0, epsilon:0.012277590292891176
#  episode :319 , total reward:-514.0, epsilon:0.012154814389962264
#  episode :320 , total reward:-268.0, epsilon:0.012033266246062642
#  episode :321 , total reward:-2006.0, epsilon:0.011912933583602014
#  episode :322 , total reward:-300.0, epsilon:0.011793804247765995
#  episode :323 , total reward:-380.0, epsilon:0.011675866205288335
#  episode :324 , total reward:-604.0, epsilon:0.011559107543235452
#  episode :325 , total reward:-309.0, epsilon:0.011443516467803097
#  episode :326 , total reward:-453.0, epsilon:0.011329081303125066
#  episode :327 , total reward:-272.0, epsilon:0.011215790490093816
#  episode :328 , total reward:-783.0, epsilon:0.011103632585192877
#  episode :329 , total reward:-195.0, epsilon:0.010992596259340948
#  episode :330 , total reward:-277.0, epsilon:0.010882670296747539
#  episode :331 , total reward:-1016.0, epsilon:0.010773843593780063
#  episode :332 , total reward:-867.0, epsilon:0.010666105157842262
#  episode :333 , total reward:-342.0, epsilon:0.01055944410626384
#  episode :334 , total reward:-1445.0, epsilon:0.0104538496652012
#  episode :335 , total reward:-780.0, epsilon:0.010349311168549188
#  episode :336 , total reward:-892.0, epsilon:0.010245818056863696
#  episode :337 , total reward:-966.0, epsilon:0.010143359876295058
#  episode :338 , total reward:-272.0, epsilon:0.010041926277532108
#  episode :339 , total reward:-1768.0, epsilon:0.01
#  episode :340 , total reward:-1226.0, epsilon:0.01
#  episode :341 , total reward:-1209.0, epsilon:0.01
#  episode :342 , total reward:-272.0, epsilon:0.01
#  episode :343 , total reward:-487.0, epsilon:0.01
#  episode :344 , total reward:-1554.0, epsilon:0.01
#  episode :345 , total reward:-416.0, epsilon:0.01
#  episode :346 , total reward:-524.0, epsilon:0.01
#  episode :347 , total reward:-776.0, epsilon:0.01
#  episode :348 , total reward:-1318.0, epsilon:0.01
#  episode :349 , total reward:-953.0, epsilon:0.01
#  episode :350 , total reward:-788.0, epsilon:0.01
#  episode :351 , total reward:-272.0, epsilon:0.01
#  episode :352 , total reward:-1402.0, epsilon:0.01
#  episode :353 , total reward:-930.0, epsilon:0.01
#  episode :354 , total reward:-457.0, epsilon:0.01
#  episode :355 , total reward:-1421.0, epsilon:0.01
#  episode :356 , total reward:-996.0, epsilon:0.01
#  episode :357 , total reward:-1383.0, epsilon:0.01
#  episode :358 , total reward:-1587.0, epsilon:0.01
#  episode :359 , total reward:-726.0, epsilon:0.01
#  episode :360 , total reward:-793.0, epsilon:0.01
#  episode :361 , total reward:-275.0, epsilon:0.01
#  episode :362 , total reward:-235.0, epsilon:0.01
#  episode :363 , total reward:-695.0, epsilon:0.01
#  episode :364 , total reward:-416.0, epsilon:0.01
#  episode :365 , total reward:-1154.0, epsilon:0.01
#  episode :366 , total reward:-242.0, epsilon:0.01
#  episode :367 , total reward:-236.0, epsilon:0.01
#  episode :368 , total reward:-273.0, epsilon:0.01
#  episode :369 , total reward:-529.0, epsilon:0.01
#  episode :370 , total reward:-990.0, epsilon:0.01
#  episode :371 , total reward:-271.0, epsilon:0.01
#  episode :372 , total reward:-273.0, epsilon:0.01
#  episode :373 , total reward:-742.0, epsilon:0.01
#  episode :374 , total reward:-997.0, epsilon:0.01
#  episode :375 , total reward:-347.0, epsilon:0.01
#  episode :376 , total reward:-887.0, epsilon:0.01
#  episode :377 , total reward:-344.0, epsilon:0.01
#  episode :378 , total reward:-747.0, epsilon:0.01
#  episode :379 , total reward:-433.0, epsilon:0.01
#  episode :380 , total reward:-310.0, epsilon:0.01
#  episode :381 , total reward:-396.0, epsilon:0.01
#  episode :382 , total reward:-1137.0, epsilon:0.01
#  episode :383 , total reward:-276.0, epsilon:0.01
#  episode :384 , total reward:-1505.0, epsilon:0.01
#  episode :385 , total reward:-239.0, epsilon:0.01
#  episode :386 , total reward:-240.0, epsilon:0.01
#  episode :387 , total reward:-289.0, epsilon:0.01
#  episode :388 , total reward:-277.0, epsilon:0.01
#  episode :389 , total reward:-269.0, epsilon:0.01
#  episode :390 , total reward:-180.0, epsilon:0.01
#  episode :391 , total reward:-422.0, epsilon:0.01
#  episode :392 , total reward:-196.0, epsilon:0.01
#  episode :393 , total reward:-266.0, epsilon:0.01
#  episode :394 , total reward:-217.0, epsilon:0.01
#  episode :395 , total reward:-338.0, epsilon:0.01
#  episode :396 , total reward:-410.0, epsilon:0.01
#  episode :397 , total reward:-300.0, epsilon:0.01
#  episode :398 , total reward:-212.0, epsilon:0.01
#  episode :399 , total reward:-181.0, epsilon:0.01
#  episode :400 , total reward:-176.0, epsilon:0.01
#  episode :401 , total reward:-276.0, epsilon:0.01
#  episode :402 , total reward:-196.0, epsilon:0.01
#  episode :403 , total reward:-285.0, epsilon:0.01
#  episode :404 , total reward:-223.0, epsilon:0.01
#  episode :405 , total reward:-229.0, epsilon:0.01
#  episode :406 , total reward:-346.0, epsilon:0.01
#  episode :407 , total reward:-268.0, epsilon:0.01
#  episode :408 , total reward:-216.0, epsilon:0.01
#  episode :409 , total reward:-289.0, epsilon:0.01
#  episode :410 , total reward:-250.0, epsilon:0.01
#  episode :411 , total reward:-218.0, epsilon:0.01
#  episode :412 , total reward:-267.0, epsilon:0.01
#  episode :413 , total reward:-197.0, epsilon:0.01
#  episode :414 , total reward:-271.0, epsilon:0.01
#  episode :415 , total reward:-248.0, epsilon:0.01
#  episode :416 , total reward:-215.0, epsilon:0.01
#  episode :417 , total reward:-196.0, epsilon:0.01
#  episode :418 , total reward:-297.0, epsilon:0.01
#  episode :419 , total reward:-241.0, epsilon:0.01
#  episode :420 , total reward:-219.0, epsilon:0.01
#  episode :421 , total reward:-234.0, epsilon:0.01
#  episode :422 , total reward:-235.0, epsilon:0.01
#  episode :423 , total reward:-379.0, epsilon:0.01
#  episode :424 , total reward:-275.0, epsilon:0.01
#  episode :425 , total reward:-311.0, epsilon:0.01
#  episode :426 , total reward:-195.0, epsilon:0.01
#  episode :427 , total reward:-371.0, epsilon:0.01
#  episode :428 , total reward:-271.0, epsilon:0.01
#  episode :429 , total reward:-274.0, epsilon:0.01
#  episode :430 , total reward:-465.0, epsilon:0.01
#  episode :431 , total reward:-554.0, epsilon:0.01
#  episode :432 , total reward:-271.0, epsilon:0.01
#  episode :433 , total reward:-265.0, epsilon:0.01
#  episode :434 , total reward:-241.0, epsilon:0.01
#  episode :435 , total reward:-215.0, epsilon:0.01
#  episode :436 , total reward:-193.0, epsilon:0.01
#  episode :437 , total reward:-276.0, epsilon:0.01
#  episode :438 , total reward:-151.0, epsilon:0.01
#  episode :439 , total reward:-276.0, epsilon:0.01
#  episode :440 , total reward:-215.0, epsilon:0.01
#  episode :441 , total reward:-317.0, epsilon:0.01
#  episode :442 , total reward:-355.0, epsilon:0.01
#  episode :443 , total reward:-182.0, epsilon:0.01
#  episode :444 , total reward:-235.0, epsilon:0.01
#  episode :445 , total reward:-458.0, epsilon:0.01
#  episode :446 , total reward:-284.0, epsilon:0.01
#  episode :447 , total reward:-578.0, epsilon:0.01
#  episode :448 , total reward:-274.0, epsilon:0.01
#  episode :449 , total reward:-289.0, epsilon:0.01
#  episode :450 , total reward:-559.0, epsilon:0.01
#  episode :451 , total reward:-415.0, epsilon:0.01
#  episode :452 , total reward:-279.0, epsilon:0.01
#  episode :453 , total reward:-637.0, epsilon:0.01
#  episode :454 , total reward:-303.0, epsilon:0.01
#  episode :455 , total reward:-213.0, epsilon:0.01
#  episode :456 , total reward:-152.0, epsilon:0.01
#  episode :457 , total reward:-213.0, epsilon:0.01
#  episode :458 , total reward:-209.0, epsilon:0.01
#  episode :459 , total reward:-306.0, epsilon:0.01
#  episode :460 , total reward:-330.0, epsilon:0.01
#  episode :461 , total reward:-213.0, epsilon:0.01
#  episode :462 , total reward:-185.0, epsilon:0.01
#  episode :463 , total reward:-273.0, epsilon:0.01
#  episode :464 , total reward:-271.0, epsilon:0.01
#  episode :465 , total reward:-328.0, epsilon:0.01
#  episode :466 , total reward:-407.0, epsilon:0.01
#  episode :467 , total reward:-214.0, epsilon:0.01
#  episode :468 , total reward:-239.0, epsilon:0.01
#  episode :469 , total reward:-292.0, epsilon:0.01
#  episode :470 , total reward:-190.0, epsilon:0.01
#  episode :471 , total reward:-213.0, epsilon:0.01
#  episode :472 , total reward:-347.0, epsilon:0.01
#  episode :473 , total reward:-159.0, epsilon:0.01
#  episode :474 , total reward:-233.0, epsilon:0.01
#  episode :475 , total reward:-212.0, epsilon:0.01
#  episode :476 , total reward:-178.0, epsilon:0.01
#  episode :477 , total reward:-254.0, epsilon:0.01
#  episode :478 , total reward:-214.0, epsilon:0.01
#  episode :479 , total reward:-236.0, epsilon:0.01
#  episode :480 , total reward:-309.0, epsilon:0.01
#  episode :481 , total reward:-183.0, epsilon:0.01
#  episode :482 , total reward:-295.0, epsilon:0.01
#  episode :483 , total reward:-216.0, epsilon:0.01
#  episode :484 , total reward:-266.0, epsilon:0.01
#  episode :485 , total reward:-273.0, epsilon:0.01
#  episode :486 , total reward:-267.0, epsilon:0.01
#  episode :487 , total reward:-273.0, epsilon:0.01
#  episode :488 , total reward:-268.0, epsilon:0.01
#  episode :489 , total reward:-235.0, epsilon:0.01
#  episode :490 , total reward:-274.0, epsilon:0.01
#  episode :491 , total reward:-176.0, epsilon:0.01
#  episode :492 , total reward:-171.0, epsilon:0.01
#  episode :493 , total reward:-173.0, epsilon:0.01
#  episode :494 , total reward:-272.0, epsilon:0.01
#  episode :495 , total reward:-349.0, epsilon:0.01
#  episode :496 , total reward:-238.0, epsilon:0.01
#  episode :497 , total reward:-296.0, epsilon:0.01
#  episode :498 , total reward:-266.0, epsilon:0.01
#  episode :499 , total reward:-235.0, epsilon:0.01
#  episode :500 , total reward:-169.0, epsilon:0.01
#  episode :501 , total reward:-333.0, epsilon:0.01
#  episode :502 , total reward:-171.0, epsilon:0.01
#  episode :503 , total reward:-238.0, epsilon:0.01
#  episode :504 , total reward:-194.0, epsilon:0.01
#  episode :505 , total reward:-176.0, epsilon:0.01
#  episode :506 , total reward:-173.0, epsilon:0.01
#  episode :507 , total reward:-270.0, epsilon:0.01
#  episode :508 , total reward:-282.0, epsilon:0.01
#  episode :509 , total reward:-231.0, epsilon:0.01
#  episode :510 , total reward:-197.0, epsilon:0.01
#  episode :511 , total reward:-231.0, epsilon:0.01
#  episode :512 , total reward:-153.0, epsilon:0.01
#  episode :513 , total reward:-191.0, epsilon:0.01
#  episode :514 , total reward:-239.0, epsilon:0.01
#  episode :515 , total reward:-147.0, epsilon:0.01
#  episode :516 , total reward:-205.0, epsilon:0.01
#  episode :517 , total reward:-139.0, epsilon:0.01
#  episode :518 , total reward:-211.0, epsilon:0.01
#  episode :519 , total reward:-179.0, epsilon:0.01
#  episode :520 , total reward:-357.0, epsilon:0.01
#  episode :521 , total reward:-276.0, epsilon:0.01
#  episode :522 , total reward:-192.0, epsilon:0.01
#  episode :523 , total reward:-283.0, epsilon:0.01
#  episode :524 , total reward:-162.0, epsilon:0.01
#  episode :525 , total reward:-228.0, epsilon:0.01
#  episode :526 , total reward:-215.0, epsilon:0.01
#  episode :527 , total reward:-231.0, epsilon:0.01
#  episode :528 , total reward:-221.0, epsilon:0.01
#  episode :529 , total reward:-243.0, epsilon:0.01
#  episode :530 , total reward:-275.0, epsilon:0.01
#  episode :531 , total reward:-434.0, epsilon:0.01
#  episode :532 , total reward:-267.0, epsilon:0.01
#  episode :533 , total reward:-226.0, epsilon:0.01
#  episode :534 , total reward:-225.0, epsilon:0.01
#  episode :535 , total reward:-305.0, epsilon:0.01
#  episode :536 , total reward:-218.0, epsilon:0.01
#  episode :537 , total reward:-237.0, epsilon:0.01
#  episode :538 , total reward:-299.0, epsilon:0.01
#  episode :539 , total reward:-234.0, epsilon:0.01
#  episode :540 , total reward:-294.0, epsilon:0.01
#  episode :541 , total reward:-227.0, epsilon:0.01
#  episode :542 , total reward:-230.0, epsilon:0.01
#  episode :543 , total reward:-231.0, epsilon:0.01
#  episode :544 , total reward:-255.0, epsilon:0.01
#  episode :545 , total reward:-249.0, epsilon:0.01
#  episode :546 , total reward:-213.0, epsilon:0.01
#  episode :547 , total reward:-224.0, epsilon:0.01
#  episode :548 , total reward:-220.0, epsilon:0.01
#  episode :549 , total reward:-234.0, epsilon:0.01
#  episode :550 , total reward:-241.0, epsilon:0.01
#  episode :551 , total reward:-210.0, epsilon:0.01
#  episode :552 , total reward:-220.0, epsilon:0.01
#  episode :553 , total reward:-210.0, epsilon:0.01
#  episode :554 , total reward:-267.0, epsilon:0.01
#  episode :555 , total reward:-174.0, epsilon:0.01
#  episode :556 , total reward:-155.0, epsilon:0.01
#  episode :557 , total reward:-230.0, epsilon:0.01
#  episode :558 , total reward:-143.0, epsilon:0.01
#  episode :559 , total reward:-211.0, epsilon:0.01
#  episode :560 , total reward:-187.0, epsilon:0.01
#  episode :561 , total reward:-216.0, epsilon:0.01
#  episode :562 , total reward:-138.0, epsilon:0.01
#  episode :563 , total reward:-228.0, epsilon:0.01
#  episode :564 , total reward:-212.0, epsilon:0.01
#  episode :565 , total reward:-221.0, epsilon:0.01
#  episode :566 , total reward:-211.0, epsilon:0.01
#  episode :567 , total reward:-216.0, epsilon:0.01
#  episode :568 , total reward:-223.0, epsilon:0.01
#  episode :569 , total reward:-227.0, epsilon:0.01
#  episode :570 , total reward:-177.0, epsilon:0.01
#  episode :571 , total reward:-204.0, epsilon:0.01
#  episode :572 , total reward:-245.0, epsilon:0.01
#  episode :573 , total reward:-221.0, epsilon:0.01
#  episode :574 , total reward:-138.0, epsilon:0.01
#  episode :575 , total reward:-257.0, epsilon:0.01
#  episode :576 , total reward:-169.0, epsilon:0.01
#  episode :577 , total reward:-221.0, epsilon:0.01
#  episode :578 , total reward:-145.0, epsilon:0.01
#  episode :579 , total reward:-144.0, epsilon:0.01
#  episode :580 , total reward:-217.0, epsilon:0.01
#  episode :581 , total reward:-200.0, epsilon:0.01
#  episode :582 , total reward:-223.0, epsilon:0.01
#  episode :583 , total reward:-180.0, epsilon:0.01
#  episode :584 , total reward:-232.0, epsilon:0.01
#  episode :585 , total reward:-207.0, epsilon:0.01
#  episode :586 , total reward:-268.0, epsilon:0.01
#  episode :587 , total reward:-179.0, epsilon:0.01
#  episode :588 , total reward:-179.0, epsilon:0.01
#  episode :589 , total reward:-271.0, epsilon:0.01
#  episode :590 , total reward:-231.0, epsilon:0.01
#  episode :591 , total reward:-169.0, epsilon:0.01
#  episode :592 , total reward:-159.0, epsilon:0.01
#  episode :593 , total reward:-285.0, epsilon:0.01
#  episode :594 , total reward:-213.0, epsilon:0.01
#  episode :595 , total reward:-155.0, epsilon:0.01
#  episode :596 , total reward:-215.0, epsilon:0.01
#  episode :597 , total reward:-212.0, epsilon:0.01
#  episode :598 , total reward:-151.0, epsilon:0.01
#  episode :599 , total reward:-212.0, epsilon:0.01
#  episode :600 , total reward:-207.0, epsilon:0.01
#  episode :601 , total reward:-210.0, epsilon:0.01
#  episode :602 , total reward:-227.0, epsilon:0.01
#  episode :603 , total reward:-273.0, epsilon:0.01
#  episode :604 , total reward:-257.0, epsilon:0.01
#  episode :605 , total reward:-312.0, epsilon:0.01
#  episode :606 , total reward:-176.0, epsilon:0.01
#  episode :607 , total reward:-228.0, epsilon:0.01
#  episode :608 , total reward:-270.0, epsilon:0.01
#  episode :609 , total reward:-203.0, epsilon:0.01
#  episode :610 , total reward:-232.0, epsilon:0.01
#  episode :611 , total reward:-240.0, epsilon:0.01
#  episode :612 , total reward:-225.0, epsilon:0.01
#  episode :613 , total reward:-616.0, epsilon:0.01
#  episode :614 , total reward:-223.0, epsilon:0.01
#  episode :615 , total reward:-213.0, epsilon:0.01
#  episode :616 , total reward:-227.0, epsilon:0.01
#  episode :617 , total reward:-214.0, epsilon:0.01
#  episode :618 , total reward:-236.0, epsilon:0.01
#  episode :619 , total reward:-185.0, epsilon:0.01
#  episode :620 , total reward:-212.0, epsilon:0.01
#  episode :621 , total reward:-179.0, epsilon:0.01
#  episode :622 , total reward:-277.0, epsilon:0.01
#  episode :623 , total reward:-234.0, epsilon:0.01
#  episode :624 , total reward:-232.0, epsilon:0.01
#  episode :625 , total reward:-214.0, epsilon:0.01
#  episode :626 , total reward:-180.0, epsilon:0.01
#  episode :627 , total reward:-174.0, epsilon:0.01
#  episode :628 , total reward:-224.0, epsilon:0.01
#  episode :629 , total reward:-230.0, epsilon:0.01
#  episode :630 , total reward:-209.0, epsilon:0.01
#  episode :631 , total reward:-222.0, epsilon:0.01
#  episode :632 , total reward:-212.0, epsilon:0.01
#  episode :633 , total reward:-210.0, epsilon:0.01
#  episode :634 , total reward:-157.0, epsilon:0.01
#  episode :635 , total reward:-210.0, epsilon:0.01
#  episode :636 , total reward:-218.0, epsilon:0.01
#  episode :637 , total reward:-225.0, epsilon:0.01
#  episode :638 , total reward:-228.0, epsilon:0.01
#  episode :639 , total reward:-264.0, epsilon:0.01
#  episode :640 , total reward:-137.0, epsilon:0.01
#  episode :641 , total reward:-197.0, epsilon:0.01
#  episode :642 , total reward:-214.0, epsilon:0.01
#  episode :643 , total reward:-214.0, epsilon:0.01
#  episode :644 , total reward:-157.0, epsilon:0.01
#  episode :645 , total reward:-210.0, epsilon:0.01
#  episode :646 , total reward:-211.0, epsilon:0.01
#  episode :647 , total reward:-140.0, epsilon:0.01
#  episode :648 , total reward:-223.0, epsilon:0.01
#  episode :649 , total reward:-152.0, epsilon:0.01
#  episode :650 , total reward:-221.0, epsilon:0.01
#  episode :651 , total reward:-229.0, epsilon:0.01
#  episode :652 , total reward:-234.0, epsilon:0.01
#  episode :653 , total reward:-294.0, epsilon:0.01
#  episode :654 , total reward:-240.0, epsilon:0.01
#  episode :655 , total reward:-399.0, epsilon:0.01
#  episode :656 , total reward:-214.0, epsilon:0.01
#  episode :657 , total reward:-169.0, epsilon:0.01
#  episode :658 , total reward:-232.0, epsilon:0.01
#  episode :659 , total reward:-207.0, epsilon:0.01
#  episode :660 , total reward:-224.0, epsilon:0.01
#  episode :661 , total reward:-269.0, epsilon:0.01
#  episode :662 , total reward:-186.0, epsilon:0.01
#  episode :663 , total reward:-208.0, epsilon:0.01
#  episode :664 , total reward:-215.0, epsilon:0.01
#  episode :665 , total reward:-176.0, epsilon:0.01
#  episode :666 , total reward:-295.0, epsilon:0.01
#  episode :667 , total reward:-179.0, epsilon:0.01
#  episode :668 , total reward:-223.0, epsilon:0.01
#  episode :669 , total reward:-199.0, epsilon:0.01
#  episode :670 , total reward:-203.0, epsilon:0.01
#  episode :671 , total reward:-212.0, epsilon:0.01
#  episode :672 , total reward:-143.0, epsilon:0.01
#  episode :673 , total reward:-227.0, epsilon:0.01
#  episode :674 , total reward:-227.0, epsilon:0.01
#  episode :675 , total reward:-208.0, epsilon:0.01
#  episode :676 , total reward:-226.0, epsilon:0.01
#  episode :677 , total reward:-278.0, epsilon:0.01
#  episode :678 , total reward:-224.0, epsilon:0.01
#  episode :679 , total reward:-266.0, epsilon:0.01
#  episode :680 , total reward:-167.0, epsilon:0.01
#  episode :681 , total reward:-257.0, epsilon:0.01
#  episode :682 , total reward:-176.0, epsilon:0.01
#  episode :683 , total reward:-218.0, epsilon:0.01
#  episode :684 , total reward:-226.0, epsilon:0.01
#  episode :685 , total reward:-265.0, epsilon:0.01
#  episode :686 , total reward:-288.0, epsilon:0.01
#  episode :687 , total reward:-171.0, epsilon:0.01
#  episode :688 , total reward:-298.0, epsilon:0.01
#  episode :689 , total reward:-165.0, epsilon:0.01
#  episode :690 , total reward:-213.0, epsilon:0.01
#  episode :691 , total reward:-208.0, epsilon:0.01
#  episode :692 , total reward:-165.0, epsilon:0.01
#  episode :693 , total reward:-145.0, epsilon:0.01
#  episode :694 , total reward:-205.0, epsilon:0.01
#  episode :695 , total reward:-214.0, epsilon:0.01
#  episode :696 , total reward:-205.0, epsilon:0.01
#  episode :697 , total reward:-221.0, epsilon:0.01
#  episode :698 , total reward:-214.0, epsilon:0.01
#  episode :699 , total reward:-220.0, epsilon:0.01
#  episode :700 , total reward:-169.0, epsilon:0.01
#  episode :701 , total reward:-258.0, epsilon:0.01
#  episode :702 , total reward:-221.0, epsilon:0.01
#  episode :703 , total reward:-172.0, epsilon:0.01
#  episode :704 , total reward:-296.0, epsilon:0.01
#  episode :705 , total reward:-252.0, epsilon:0.01
#  episode :706 , total reward:-262.0, epsilon:0.01
#  episode :707 , total reward:-208.0, epsilon:0.01
#  episode :708 , total reward:-142.0, epsilon:0.01
#  episode :709 , total reward:-164.0, epsilon:0.01
#  episode :710 , total reward:-164.0, epsilon:0.01
#  episode :711 , total reward:-226.0, epsilon:0.01
#  episode :712 , total reward:-137.0, epsilon:0.01
#  episode :713 , total reward:-209.0, epsilon:0.01
#  episode :714 , total reward:-148.0, epsilon:0.01
#  episode :715 , total reward:-202.0, epsilon:0.01
#  episode :716 , total reward:-201.0, epsilon:0.01
#  episode :717 , total reward:-197.0, epsilon:0.01
#  episode :718 , total reward:-228.0, epsilon:0.01
#  episode :719 , total reward:-228.0, epsilon:0.01
#  episode :720 , total reward:-238.0, epsilon:0.01
#  episode :721 , total reward:-477.0, epsilon:0.01
#  episode :722 , total reward:-337.0, epsilon:0.01
#  episode :723 , total reward:-280.0, epsilon:0.01
#  episode :724 , total reward:-258.0, epsilon:0.01
#  episode :725 , total reward:-464.0, epsilon:0.01
#  episode :726 , total reward:-239.0, epsilon:0.01
#  episode :727 , total reward:-255.0, epsilon:0.01
#  episode :728 , total reward:-489.0, epsilon:0.01
#  episode :729 , total reward:-261.0, epsilon:0.01
#  episode :730 , total reward:-294.0, epsilon:0.01
#  episode :731 , total reward:-164.0, epsilon:0.01
#  episode :732 , total reward:-224.0, epsilon:0.01
#  episode :733 , total reward:-254.0, epsilon:0.01
#  episode :734 , total reward:-215.0, epsilon:0.01
#  episode :735 , total reward:-173.0, epsilon:0.01
#  episode :736 , total reward:-227.0, epsilon:0.01
#  episode :737 , total reward:-246.0, epsilon:0.01
#  episode :738 , total reward:-243.0, epsilon:0.01
#  episode :739 , total reward:-231.0, epsilon:0.01
#  episode :740 , total reward:-232.0, epsilon:0.01
#  episode :741 , total reward:-177.0, epsilon:0.01
#  episode :742 , total reward:-234.0, epsilon:0.01
#  episode :743 , total reward:-270.0, epsilon:0.01
#  episode :744 , total reward:-224.0, epsilon:0.01
#  episode :745 , total reward:-257.0, epsilon:0.01
#  episode :746 , total reward:-198.0, epsilon:0.01
#  episode :747 , total reward:-242.0, epsilon:0.01
#  episode :748 , total reward:-222.0, epsilon:0.01
#  episode :749 , total reward:-265.0, epsilon:0.01
#  episode :750 , total reward:-295.0, epsilon:0.01
#  episode :751 , total reward:-224.0, epsilon:0.01
#  episode :752 , total reward:-210.0, epsilon:0.01
#  episode :753 , total reward:-234.0, epsilon:0.01
#  episode :754 , total reward:-177.0, epsilon:0.01
#  episode :755 , total reward:-277.0, epsilon:0.01
#  episode :756 , total reward:-330.0, epsilon:0.01
#  episode :757 , total reward:-170.0, epsilon:0.01
#  episode :758 , total reward:-263.0, epsilon:0.01
#  episode :759 , total reward:-264.0, epsilon:0.01
#  episode :760 , total reward:-445.0, epsilon:0.01
#  episode :761 , total reward:-259.0, epsilon:0.01
#  episode :762 , total reward:-207.0, epsilon:0.01
#  episode :763 , total reward:-236.0, epsilon:0.01
#  episode :764 , total reward:-207.0, epsilon:0.01
#  episode :765 , total reward:-228.0, epsilon:0.01
#  episode :766 , total reward:-248.0, epsilon:0.01
#  episode :767 , total reward:-261.0, epsilon:0.01
#  episode :768 , total reward:-222.0, epsilon:0.01
#  episode :769 , total reward:-168.0, epsilon:0.01
#  episode :770 , total reward:-222.0, epsilon:0.01
#  episode :771 , total reward:-220.0, epsilon:0.01
#  episode :772 , total reward:-223.0, epsilon:0.01
#  episode :773 , total reward:-223.0, epsilon:0.01
#  episode :774 , total reward:-224.0, epsilon:0.01
#  episode :775 , total reward:-199.0, epsilon:0.01
#  episode :776 , total reward:-229.0, epsilon:0.01
#  episode :777 , total reward:-230.0, epsilon:0.01
#  episode :778 , total reward:-190.0, epsilon:0.01
#  episode :779 , total reward:-231.0, epsilon:0.01
#  episode :780 , total reward:-237.0, epsilon:0.01
#  episode :781 , total reward:-186.0, epsilon:0.01
#  episode :782 , total reward:-227.0, epsilon:0.01
#  episode :783 , total reward:-210.0, epsilon:0.01
#  episode :784 , total reward:-202.0, epsilon:0.01
#  episode :785 , total reward:-224.0, epsilon:0.01
#  episode :786 , total reward:-204.0, epsilon:0.01
#  episode :787 , total reward:-230.0, epsilon:0.01
#  episode :788 , total reward:-202.0, epsilon:0.01
#  episode :789 , total reward:-197.0, epsilon:0.01
#  episode :790 , total reward:-227.0, epsilon:0.01
#  episode :791 , total reward:-225.0, epsilon:0.01
#  episode :792 , total reward:-224.0, epsilon:0.01
#  episode :793 , total reward:-231.0, epsilon:0.01
#  episode :794 , total reward:-244.0, epsilon:0.01
#  episode :795 , total reward:-227.0, epsilon:0.01
#  episode :796 , total reward:-244.0, epsilon:0.01
#  episode :797 , total reward:-225.0, epsilon:0.01
#  episode :798 , total reward:-218.0, epsilon:0.01
#  episode :799 , total reward:-224.0, epsilon:0.01
#  episode :800 , total reward:-202.0, epsilon:0.01
#  episode :801 , total reward:-244.0, epsilon:0.01
#  episode :802 , total reward:-179.0, epsilon:0.01
#  episode :803 , total reward:-260.0, epsilon:0.01
#  episode :804 , total reward:-234.0, epsilon:0.01
#  episode :805 , total reward:-218.0, epsilon:0.01
#  episode :806 , total reward:-214.0, epsilon:0.01
#  episode :807 , total reward:-226.0, epsilon:0.01
#  episode :808 , total reward:-232.0, epsilon:0.01
#  episode :809 , total reward:-195.0, epsilon:0.01
#  episode :810 , total reward:-260.0, epsilon:0.01
#  episode :811 , total reward:-226.0, epsilon:0.01
#  episode :812 , total reward:-209.0, epsilon:0.01
#  episode :813 , total reward:-224.0, epsilon:0.01
#  episode :814 , total reward:-241.0, epsilon:0.01
#  episode :815 , total reward:-189.0, epsilon:0.01
#  episode :816 , total reward:-217.0, epsilon:0.01
#  episode :817 , total reward:-225.0, epsilon:0.01
#  episode :818 , total reward:-191.0, epsilon:0.01
#  episode :819 , total reward:-223.0, epsilon:0.01
#  episode :820 , total reward:-207.0, epsilon:0.01
#  episode :821 , total reward:-222.0, epsilon:0.01
#  episode :822 , total reward:-223.0, epsilon:0.01
#  episode :823 , total reward:-216.0, epsilon:0.01
#  episode :824 , total reward:-196.0, epsilon:0.01
#  episode :825 , total reward:-223.0, epsilon:0.01
#  episode :826 , total reward:-232.0, epsilon:0.01
#  episode :827 , total reward:-229.0, epsilon:0.01
#  episode :828 , total reward:-186.0, epsilon:0.01
#  episode :829 , total reward:-220.0, epsilon:0.01
#  episode :830 , total reward:-229.0, epsilon:0.01
#  episode :831 , total reward:-224.0, epsilon:0.01
#  episode :832 , total reward:-189.0, epsilon:0.01
#  episode :833 , total reward:-179.0, epsilon:0.01
#  episode :834 , total reward:-201.0, epsilon:0.01
#  episode :835 , total reward:-229.0, epsilon:0.01
#  episode :836 , total reward:-205.0, epsilon:0.01
#  episode :837 , total reward:-202.0, epsilon:0.01
#  episode :838 , total reward:-228.0, epsilon:0.01
#  episode :839 , total reward:-227.0, epsilon:0.01
#  episode :840 , total reward:-215.0, epsilon:0.01
#  episode :841 , total reward:-183.0, epsilon:0.01
#  episode :842 , total reward:-202.0, epsilon:0.01
#  episode :843 , total reward:-227.0, epsilon:0.01
#  episode :844 , total reward:-189.0, epsilon:0.01
#  episode :845 , total reward:-229.0, epsilon:0.01
#  episode :846 , total reward:-234.0, epsilon:0.01
#  episode :847 , total reward:-235.0, epsilon:0.01
#  episode :848 , total reward:-187.0, epsilon:0.01
#  episode :849 , total reward:-143.0, epsilon:0.01
#  episode :850 , total reward:-226.0, epsilon:0.01
#  episode :851 , total reward:-224.0, epsilon:0.01
#  episode :852 , total reward:-238.0, epsilon:0.01
#  episode :853 , total reward:-237.0, epsilon:0.01
#  episode :854 , total reward:-192.0, epsilon:0.01
#  episode :855 , total reward:-199.0, epsilon:0.01
#  episode :856 , total reward:-188.0, epsilon:0.01
#  episode :857 , total reward:-241.0, epsilon:0.01
#  episode :858 , total reward:-200.0, epsilon:0.01
#  episode :859 , total reward:-190.0, epsilon:0.01
#  episode :860 , total reward:-190.0, epsilon:0.01
#  episode :861 , total reward:-231.0, epsilon:0.01
#  episode :862 , total reward:-188.0, epsilon:0.01
#  episode :863 , total reward:-239.0, epsilon:0.01
#  episode :864 , total reward:-199.0, epsilon:0.01
#  episode :865 , total reward:-204.0, epsilon:0.01
#  episode :866 , total reward:-189.0, epsilon:0.01
#  episode :867 , total reward:-189.0, epsilon:0.01
#  episode :868 , total reward:-208.0, epsilon:0.01
#  episode :869 , total reward:-186.0, epsilon:0.01
#  episode :870 , total reward:-209.0, epsilon:0.01
#  episode :871 , total reward:-191.0, epsilon:0.01
#  episode :872 , total reward:-188.0, epsilon:0.01
#  episode :873 , total reward:-209.0, epsilon:0.01
#  episode :874 , total reward:-271.0, epsilon:0.01
#  episode :875 , total reward:-260.0, epsilon:0.01
#  episode :876 , total reward:-225.0, epsilon:0.01
#  episode :877 , total reward:-224.0, epsilon:0.01
#  episode :878 , total reward:-228.0, epsilon:0.01
#  episode :879 , total reward:-225.0, epsilon:0.01
#  episode :880 , total reward:-196.0, epsilon:0.01
#  episode :881 , total reward:-188.0, epsilon:0.01
#  episode :882 , total reward:-208.0, epsilon:0.01
#  episode :883 , total reward:-189.0, epsilon:0.01
#  episode :884 , total reward:-230.0, epsilon:0.01
#  episode :885 , total reward:-192.0, epsilon:0.01
#  episode :886 , total reward:-198.0, epsilon:0.01
#  episode :887 , total reward:-231.0, epsilon:0.01
#  episode :888 , total reward:-186.0, epsilon:0.01
#  episode :889 , total reward:-187.0, epsilon:0.01
#  episode :890 , total reward:-226.0, epsilon:0.01
#  episode :891 , total reward:-204.0, epsilon:0.01
#  episode :892 , total reward:-219.0, epsilon:0.01
#  episode :893 , total reward:-203.0, epsilon:0.01
#  episode :894 , total reward:-231.0, epsilon:0.01
#  episode :895 , total reward:-231.0, epsilon:0.01
#  episode :896 , total reward:-228.0, epsilon:0.01
#  episode :897 , total reward:-230.0, epsilon:0.01
#  episode :898 , total reward:-173.0, epsilon:0.01
#  episode :899 , total reward:-223.0, epsilon:0.01
#  episode :900 , total reward:-227.0, epsilon:0.01
#  episode :901 , total reward:-242.0, epsilon:0.01
#  episode :902 , total reward:-291.0, epsilon:0.01
#  episode :903 , total reward:-241.0, epsilon:0.01
#  episode :904 , total reward:-219.0, epsilon:0.01
#  episode :905 , total reward:-254.0, epsilon:0.01
#  episode :906 , total reward:-491.0, epsilon:0.01
#  episode :907 , total reward:-317.0, epsilon:0.01
#  episode :908 , total reward:-240.0, epsilon:0.01
#  episode :909 , total reward:-160.0, epsilon:0.01
#  episode :910 , total reward:-205.0, epsilon:0.01
#  episode :911 , total reward:-211.0, epsilon:0.01
#  episode :912 , total reward:-219.0, epsilon:0.01
#  episode :913 , total reward:-225.0, epsilon:0.01
#  episode :914 , total reward:-241.0, epsilon:0.01
#  episode :915 , total reward:-226.0, epsilon:0.01
#  episode :916 , total reward:-234.0, epsilon:0.01
#  episode :917 , total reward:-187.0, epsilon:0.01
#  episode :918 , total reward:-228.0, epsilon:0.01
#  episode :919 , total reward:-184.0, epsilon:0.01
#  episode :920 , total reward:-226.0, epsilon:0.01
#  episode :921 , total reward:-188.0, epsilon:0.01
#  episode :922 , total reward:-239.0, epsilon:0.01
#  episode :923 , total reward:-231.0, epsilon:0.01
#  episode :924 , total reward:-201.0, epsilon:0.01
#  episode :925 , total reward:-203.0, epsilon:0.01
#  episode :926 , total reward:-227.0, epsilon:0.01
#  episode :927 , total reward:-217.0, epsilon:0.01
#  episode :928 , total reward:-209.0, epsilon:0.01
#  episode :929 , total reward:-219.0, epsilon:0.01
#  episode :930 , total reward:-205.0, epsilon:0.01
#  episode :931 , total reward:-197.0, epsilon:0.01
#  episode :932 , total reward:-207.0, epsilon:0.01
#  episode :933 , total reward:-198.0, epsilon:0.01
#  episode :934 , total reward:-269.0, epsilon:0.01
#  episode :935 , total reward:-207.0, epsilon:0.01
#  episode :936 , total reward:-149.0, epsilon:0.01
#  episode :937 , total reward:-219.0, epsilon:0.01
#  episode :938 , total reward:-211.0, epsilon:0.01
#  episode :939 , total reward:-229.0, epsilon:0.01
#  episode :940 , total reward:-234.0, epsilon:0.01
#  episode :941 , total reward:-177.0, epsilon:0.01
#  episode :942 , total reward:-147.0, epsilon:0.01
#  episode :943 , total reward:-224.0, epsilon:0.01
#  episode :944 , total reward:-144.0, epsilon:0.01
#  episode :945 , total reward:-227.0, epsilon:0.01
#  episode :946 , total reward:-233.0, epsilon:0.01
#  episode :947 , total reward:-244.0, epsilon:0.01
#  episode :948 , total reward:-233.0, epsilon:0.01
#  episode :949 , total reward:-203.0, epsilon:0.01
#  episode :950 , total reward:-217.0, epsilon:0.01
#  episode :951 , total reward:-226.0, epsilon:0.01
#  episode :952 , total reward:-266.0, epsilon:0.01
#  episode :953 , total reward:-241.0, epsilon:0.01
#  episode :954 , total reward:-263.0, epsilon:0.01
#  episode :955 , total reward:-476.0, epsilon:0.01
#  episode :956 , total reward:-298.0, epsilon:0.01
#  episode :957 , total reward:-261.0, epsilon:0.01
#  episode :958 , total reward:-218.0, epsilon:0.01
#  episode :959 , total reward:-247.0, epsilon:0.01
#  episode :960 , total reward:-253.0, epsilon:0.01
#  episode :961 , total reward:-251.0, epsilon:0.01
#  episode :962 , total reward:-223.0, epsilon:0.01
#  episode :963 , total reward:-215.0, epsilon:0.01
#  episode :964 , total reward:-219.0, epsilon:0.01
#  episode :965 , total reward:-254.0, epsilon:0.01
#  episode :966 , total reward:-248.0, epsilon:0.01
#  episode :967 , total reward:-280.0, epsilon:0.01
#  episode :968 , total reward:-164.0, epsilon:0.01
#  episode :969 , total reward:-248.0, epsilon:0.01
#  episode :970 , total reward:-244.0, epsilon:0.01
#  episode :971 , total reward:-166.0, epsilon:0.01
#  episode :972 , total reward:-206.0, epsilon:0.01
#  episode :973 , total reward:-205.0, epsilon:0.01
#  episode :974 , total reward:-228.0, epsilon:0.01
#  episode :975 , total reward:-173.0, epsilon:0.01
#  episode :976 , total reward:-202.0, epsilon:0.01
#  episode :977 , total reward:-162.0, epsilon:0.01
#  episode :978 , total reward:-211.0, epsilon:0.01
#  episode :979 , total reward:-204.0, epsilon:0.01
#  episode :980 , total reward:-230.0, epsilon:0.01
#  episode :981 , total reward:-219.0, epsilon:0.01
#  episode :982 , total reward:-214.0, epsilon:0.01
#  episode :983 , total reward:-231.0, epsilon:0.01
#  episode :984 , total reward:-251.0, epsilon:0.01
#  episode :985 , total reward:-263.0, epsilon:0.01
#  episode :986 , total reward:-269.0, epsilon:0.01
#  episode :987 , total reward:-474.0, epsilon:0.01
#  episode :988 , total reward:-258.0, epsilon:0.01
#  episode :989 , total reward:-147.0, epsilon:0.01
#  episode :990 , total reward:-208.0, epsilon:0.01
#  episode :991 , total reward:-205.0, epsilon:0.01
#  episode :992 , total reward:-213.0, epsilon:0.01
#  episode :993 , total reward:-218.0, epsilon:0.01
#  episode :994 , total reward:-219.0, epsilon:0.01
#  episode :995 , total reward:-219.0, epsilon:0.01
#  episode :996 , total reward:-249.0, epsilon:0.01
#  episode :997 , total reward:-236.0, epsilon:0.01
#  episode :998 , total reward:-209.0, epsilon:0.01
#  episode :999 , total reward:-164.0, epsilon:0.01
